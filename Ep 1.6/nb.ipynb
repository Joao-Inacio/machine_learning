# %% [markdown]
# # **Naive Bayes - Machine Learning 16**

# %% [markdown]
# ### Bibliotecas

# %%
# Libs
import numpy as np
import pandas as pd

# %% [markdown]
# ### Base de Dados

# %%
# Função de carregamento de dados
def carregarDados(arquivo, deli):
    ds = pd.read_csv(arquivo, sep=deli)
    # Amostra
    X = ds.iloc[:,:-1].values
    # Variável independente 
    y = ds.iloc[:,-1].values
    return X, y, ds

# %% [markdown]
# ### Substituído Valores Faltante

# %%
# Função de Substituição dos valores
def valorFaltante(X, inicioColuna, fimColuna):
    from sklearn.impute import SimpleImputer
    imputer = SimpleImputer(missing_values=np.nan, strategy='median')
    X[:,inicioColuna:fimColuna + 1] = imputer.fit_transform(X[:,inicioColuna:fimColuna + 1])
    return X

# %% [markdown]
# ### Transformando os valores

# %%
# Função de Transformação dos Valores
def transform(X):
    from sklearn.preprocessing import LabelEncoder
    labelencoder_X = LabelEncoder()
    X[:, 0] = labelencoder_X.fit_transform(X[:, 0])

    #one hot encoding
    D = pd.get_dummies(X[:,0]).values
    
    X = X[:,1:]
    for ii in range(0, D.shape[1]):
        X = np.insert(X, X.shape[1], D[:,ii], axis=1)
    X = X[:,:X.shape[1] - 1]

    return X

# %% [markdown]
# ### Dividindo a base de Treino e Teste

# %%
# Função de Treino e Teste
def treinoTeste(X, y, testSize, rs):
    from sklearn.model_selection import train_test_split
    XTrain, XTest, yTrain, yTest = train_test_split(X, y, test_size=testSize, random_state=rs)
    return XTrain, XTest, yTrain, yTest

# %% [markdown]
# ### Normalizando o Conjunto de Dados

# %%
# Função de Normalização de dados
def normalizarDados(X):
    from sklearn.preprocessing import StandardScaler
    scaleobj = StandardScaler()
    X = scaleobj.fit_transform(X.astype(float))

    return X, scaleobj

# %% [markdown]
# ### Classe de Classificação do Modelo

# %%
# Função de previsão
def previsaoModelo(regressor , X_test):
    previsao = regressor.predict(X_test[0])
    return previsao

# Função de matriz de confusão 
def matrizConfusao(regressor, y_Test, y_Pred):
    from sklearn.metrics import confusion_matrix
    cm = confusion_matrix(y_Test, y_Pred)

    return cm

# %% [markdown]
# ### Modelo Naive Bayes

# %%
# Classe do Modelo SVM
def computarModelo(X_train, y_train):
    from sklearn.naive_bayes import GaussianNB

    classifier = GaussianNB()
    classifier.fit(X_train[0], y_train)

    return classifier

# %% [markdown]
# ### Valor da Accuracy

# %%
# Função para calcular o valor de Accuracy
def valorAccuracy(matrizConfusao):
    valor_accuracy = (matrizConfusao[0][0] + matrizConfusao[1][1]) / (matrizConfusao[0][0] + matrizConfusao[1][0] + matrizConfusao[0][1] + matrizConfusao[1][1])
    return valor_accuracy * 100

# %% [markdown]
# ### Rodando Todas as Funções

# %%
# Função que roda todas as funções nos dados do titanic
def rodarModeloTitan(dados, rs):
    X, y, csv = carregarDados(dados, ',')
    X = valorFaltante(X, 2, 3)

    X = transform(X)
    X = transform(X)

    XTrain, XTest, yTrain, yTest = treinoTeste(X, y, 0.15, rs)
    XTrain = normalizarDados(XTrain)
    XTest = normalizarDados(XTest)

    classifier = computarModelo(XTrain, yTrain)
    y_pred = previsaoModelo(classifier, XTest)
    return matrizConfusao(classifier, y_pred, yTest)

# %%
# Função que roda todas as funções nos dados do Câncer de Próstata 
def rodarModeloCP(dados, rs):
    X, y, csv = carregarDados(dados, ',')

    XTrain, XTest, yTrain, yTest = treinoTeste(X, y, 0.15, rs)
    XTrain = normalizarDados(XTrain)
    XTest = normalizarDados(XTest)

    regressor = computarModelo(XTrain, yTrain)
    y_pred = previsaoModelo(regressor, XTest)
    return matrizConfusao(regressor, y_pred, yTest)

# %% [markdown]
# ### Resultado Final

# %%
# Rodando a função no dados de titanic
import numpy as np
nbArray = []
for i in range(0, 100):
    cmSVM = rodarModeloTitan('../data/titanic.csv', i)
    nbArray.append(valorAccuracy(cmSVM))

print(f'Média do Naive Bayes: {np.mean(nbArray)}')
print(f'Desvio padrão do Naive Bayes: {np.std(nbArray)}')

# Visualizando os resultados no gráfico
import matplotlib.pyplot as plt
plt.plot(nbArray)
plt.title('Naive Bayes do Titanic')
plt.ylabel("Acurácia")
plt.xlabel("Tentativas")
plt.show()
# Out:
# Média do Naive Bayes: 77.73134328358209
# Desvio padrão do Naive Bayes: 3.4404846648892904

# %%
# Rodando a função no dados de Câncer de Próstata
nbArrayCP = []
for i in range(0, 100):
    cmSVM = rodarModeloCP('../data/pc.csv', i)
    nbArrayCP.append(valorAccuracy(cmSVM))

print(f'Média do Naive Bayes: {np.mean(nbArrayCP)}')
print(f'Desvio padrão do Naive Bayes: {np.std(nbArrayCP)}')

# Visualizando os resultados no gráfico
import matplotlib.pyplot as plt
plt.plot(nbArrayCP)
plt.title('Naive Bayes de Câncer de Próstata')
plt.ylabel("Acurácia")
plt.xlabel("Tentativas")
plt.show()
# Out:
# Média do Naive Bayes: 86.0
# Desvio padrão do Naive Bayes: 9.067647005823629

# %%
# Valor máximo da Acurácia dos modelo de Naive Bayes
print(f'Valor máximo da Acurácia do Titanic: {max(nbArray)}')
print(f'Valor máximo da Acurácia do Câncer de Próstata: {max(nbArrayCP)}')
# Valor mínimo da Acurácia dos modelo de Naive Bayes
print(f'Valor mínimo da Acurácia do Titanic: {min(nbArray)}')
print(f'Valor mínimo da Acurácia do Câncer de Próstata: {min(nbArrayCP)}')
# Out:
# Valor máximo da Acurácia do Titanic: 84.32835820895522
# Valor máximo da Acurácia do Câncer de Próstata: 100.0
# Valor mínimo da Acurácia do Titanic: 70.8955223880597
# Valor mínimo da Acurácia do Câncer de Próstata: 53.333333333333336
